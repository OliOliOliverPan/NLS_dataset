# %%
import pandas as pd
import os
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

folder_path = '/afs/inf.ed.ac.uk/user/s21/s2103701/Desktop/nls-catalogue-published-material_dc'

file_prefix = 'BIBLIOGRAPHIC_11573881650004341_'

file_end = '.xml'

data = pd.DataFrame()

for i in range(1,52):
    curr_file = file_prefix + str(i) + file_end
    file_path = os.path.join(folder_path, curr_file)

    df = pd.read_xml(file_path)

    data = pd.concat([data, df], ignore_index = True)

data
# Out:
#                                                      title  \
# 0                                                 Travel /
# 1                 Resource book of test items in chemistry
# 2                              Arbitration for contractors
# 3        Armorial bearings of the sovereigns of England...
# 4        Sharing caring : caring, equal opportunities a...
# ...                                                    ...
# 5091422  Symfoni Nr. 5, Opus 50 = Symphony no. 5, opus ...
# 5091423  Music for violin : from 'El Amor brujo' = Musi...
# 5091424  Fox trot ; and Celebration rag : for SATB reco...
# 5091425  Fieber : Tondichtung : für Tenor und Orcheste...
# 5091426                             Tu es petrus : motet /
#
#                                                    creator           type  \
# 0                                Leeson, Edward,1947-2011.           text
# 1                            Jenkins, E. W.(Edgar William)           text
# 2                                   Stephenson, Douglas A.           text
# 3                   Standing Conference for Local History.           text
# 4                                     Thompson, Catherine.           text
# ...                                                    ...            ...
# 5091422                              Fjeldsøe, Michael.edt  notated music
# 5091423  Falla, Manuel de,1876-1946.Amor brujo.Danza ri...  notated music
# 5091424                                   Hilling, Lyndon.  notated music
# 5091425                            Lehár, Franz1870-1948.  notated music
# 5091426                                       Lewin, Greg.  notated music
#
#                                                  publisher    date language  \
# 0                                         London J. Murray    1980      eng
# 1                                            London Murray    1981      eng
# 2                                          Northwood Books    1982      NaN
# 3        London Bedford Square Press [for the] Standing...    1977      eng
# 4                                   Community Care Project  [1985]      NaN
# ...                                                    ...     ...      ...
# 5091422               Copenhagen : Edition Wilhelm Hansen,   1998.      zxx
# 5091423                            London : Chester Music,  c1996.      zxx
# 5091424                               London : Theo Wyatt,  c1984.      eng
# 5091425                              London Glocken Verlag  [1995]      ger
# 5091426                        Stafford : Hawthorns Music,  c1995.      zxx
#
#                          subject  \
# 0        Short stories, English.
# 1                      Chemistry
# 2                           None
# 3                       Heraldry
# 4                           None
# ...                          ...
# 5091422               Symphonies
# 5091423                  Ballets
# 5091424                     None
# 5091425                     None
# 5091426                     None
#
#                                                description coverage relation  \
# 0                                                     None     None     None
# 1                                        Bibliography: p15     None     None
# 2                                                     None     None     None
# 3                                    Bibliography: p.29-31     None     None
# 4                                                     None     None     None
# ...                                                    ...      ...      ...
# 5091422  "Critical commentary," "Filiation and evaluati...     None     None
# 5091423  Dance of terror (Danza del terror) -- Pantomim...     None     None
# 5091424                                           Publ.no.     None     None
# 5091425                                               2827     None     None
# 5091426                                               None     None     None
#
#         rights identifier format
# 0         None       None   None
# 1         None       None   None
# 2         None       None   None
# 3         None       None   None
# 4         None       None   None
# ...        ...        ...    ...
# 5091422   None       None   None
# 5091423   None       None   None
# 5091424   None       None   None
# 5091425   None       None   None
# 5091426   None       None   None
#
# [5091427 rows x 13 columns]

# %%
unique_types = pd.unique(data['type'])

# %%
# Tokenization
# tokenized_data = [word_tokenize(text.lower()) for text in unique_types if text is not None]
# tokenized_data
# # Stopword removal
# stop_words = set(stopwords.words("english"))
# filtered_data = [[word for word in text if word not in stop_words] for text in tokenized_data]

# # Lemmatization
# lemmatizer = WordNetLemmatizer()
# lemmatized_data = [[lemmatizer.lemmatize(word) for word in text] for text in filtered_data]

# # Convert list of tokens back to strings
# processed_data = [" ".join(text) for text in lemmatized_data]

# processed_data

# %%
import re

def split_words_in_list(words_list):
    result = []
    for text in words_list:
        # Split the text based on spaces or transitions from lowercase to uppercase
        words = re.findall(r'[A-Z]?[a-z]+|[A-Z]+(?=[A-Z]|$)', text)
        result.append(words)
    return result

unique_types = unique_types[np.logical_not(np.equal(unique_types, None))]
cleaned_unique_types = split_words_in_list(unique_types)

# %%
def categorize_data(processed_words_list, book_keywords, academic_keywords, 
                    audio_keywords, art_keywords, computer_keywords, data_keywords):
    categorized_data = {}
    for entry in processed_words_list:
        is_academic = any(word.lower() in academic_keywords or any(keyword.lower() in word.lower() for keyword in academic_keywords) for word in entry)
        if is_academic:
            categorized_data[' '.join(entry)] = 'academic'
        else:
            is_recording = any(word.lower() in audio_keywords or any(keyword.lower() in word.lower() for keyword in audio_keywords) for word in entry)
            if is_recording:
                categorized_data[' '.join(entry)] = 'recording'
            else:
                is_art = any(word.lower() in art_keywords or any(keyword.lower() in word.lower() for keyword in art_keywords) for word in entry)
                if is_art:
                    categorized_data[' '.join(entry)] = 'art'
                else:
                    is_computer = any(word.lower() in computer_keywords or any(keyword.lower() in word.lower() for keyword in computer_keywords) for word in entry)
                    if is_computer:
                        categorized_data[' '.join(entry)] = 'computer'
                    else:
                        is_data = any(word.lower() in book_keywords or any(keyword.lower() in word.lower() for keyword in data_keywords) for word in entry)
                        if is_data:
                            categorized_data[' '.join(entry)] = 'data'
                        else:    
                            is_book = any(word.lower() in book_keywords or any(keyword.lower() in word.lower() for keyword in book_keywords) for word in entry)
                            if is_book:
                                categorized_data[' '.join(entry)] = 'book'
                            else:
                                categorized_data[' '.join(entry)] = 'unknown'
    
    return categorized_data

# Example keywords related to books
book_keywords = [
    "book", "story", "stories", "fiction", "biography", "tale", "interpretation",
    "journal", "broadside", "proclamation", "read", "translation", "almanac", 'Brtoadsides',
    "periodi", "newspaper", "magazine","novel", "print", "text", "poetry", "poem","poezja", "sonnet","humor", "guide", "eriodical",
    "memoir", "manual", "encyclopedia", "dictionar","recipe", "binding", "publica", "publish", "newsletter", "writing", "constitution"
]

academic_keywords = [
    "paper", "proceeding", "dissertation", "academic", "conference", "thesis", "annotation", "presentation", "sample", "proof", "guildeline", "treaties",
     "exam", "guide", "law", "essay", "manuscript", "studies", "report", "literature", "quotation", "teach", "theory", "anecdote", "archive", "review", "reference", "outline",
    "literary", "document", "bibliograph","criticism", "lecture", "abstracts", "survey", "work", "exam","problem", "question", "grammar","histor", "scientific"
]

audio_keywords = ["song","sing","music","recording", "recorded","score","sound","audio", "symphon", "sonata","anthem","opera","rhyme","ballad","folklore", "speech",
                  "narrat","commenta", "radio", "jazz", "concert","film","video", "dialog", "interview"]

art_keywords = ["art","sculpture","paint","draw","theatre","theater","play","drama", "advertise", "portrait",
                "picture", "pictorial", "image","photo", "cartoon", "comic","manga", "poster", "lyric", "color", "game"]


computer_keywords = ["software","computer", "http", "internet", "disc", "disk","code",
                     "web", "program", "database","electronic", "online", "Elektronische"]

data_keywords = ["map", "statisti", "chart", "graph", "atlas", "sheet", "address",
                 "directory", "directories", "list","catalog","collection","form" ]

# Apply categorization function to the processed words list
categorized_data = categorize_data(cleaned_unique_types, book_keywords, academic_keywords,
                                   audio_keywords, art_keywords, computer_keywords, data_keywords)


# Get the number of items with the value of "unknown"
unknown_count = sum(1 for category in categorized_data.values() if category == 'unknown')

print("Number of items with value 'unknown':", unknown_count)
# Out:
# Number of items with value 'unknown': 700

# %%
unknown_keys = [key for key, value in categorized_data.items() if value == 'unknown']

unknown_keys
# Out:
# ['Trivia and miscellanea fast O Co L fst',
#  'Aufsatzsammlung',
#  'Bildungsromans gsafd',
#  'Bildungsromane',
#  'mixed material',
#  'Sermons rbgenr',
#  'Records and correspondence fast O Co L fst',
#  'riodiques rvmgf',
#  'Zeitschrift gnd content',
#  'Madrid swd',
#  'Designs and plans fast O Co L fst',
#  'Llibres electr nicsthub',
#  'Patterns fast O Co L fst',
#  'three dimensional object',
#  'Sources fast O Co L fst',
#  'Satire',
#  'Digests fast O Co L fst',
#  'Miscellanea fast O Co L fst',
#  'Genealogyfast O Co L fst',
#  'Specimensfast O Co L fst',
#  'Chick lit',
#  'Trials litigation etc fast O Co L fst',
#  'Terminology fast O Co L fst',
#  'Sermons English Scotland rbgenr',
#  'Librettos Italy Rome lcsh',
#  'Accounts Estate Scotland local',
#  'Bildungsroman lcsh',
#  'Reiseberichtswd',
#  'Aufsatzsammlung swd',
#  'Bildungsromane gsafd',
#  'Festschriften fast O Co L fst',
#  'Thrillers gsafd',
#  'Romans homosexuels rvmgf Ca QQ La RVMG',
#  'Salt Lake City Utah swd',
#  'Lyon swd',
#  'Genealogy fast O Co L fst',
#  'Specimens fast O Co L fst',
#  'Limited edition',
#  'Aufsatzsammlunggnd',
#  'Classification fast O Co L fst',
#  'Tragedies gsafd',
#  'Indulgences Germany rbgenr',
#  'Zeitschrift swd',
#  'Paris swd',
#  'Revistes electr niques thub',
#  'Dystopias gsafd',
#  'Brieven vorm gtt',
#  'Patents fast O Co L fst',
#  'Globes lcgft',
#  'Madras swd',
#  'Kongress London',
#  'Bildungsroman gsafd',
#  'Indulgencesrbgenr',
#  'Indulgences rbgenr',
#  'Dystopias',
#  'C RO Ms lcsh',
#  'Petitions Great Britain rbgenr',
#  'Parables fast O Co L fst',
#  'Kopenhagen swd',
#  'Sermons Scotland Aberdeen rbgenr',
#  'Allegories gsafd',
#  'C ROM Slcsh',
#  'Official gazettes lcgft',
#  'Rules fast O Co L fst',
#  'Prayers rbgenr',
#  'Zeitschriftswd',
#  'Kongressswd',
#  'Personal correspondence fast O Co L fst',
#  'Murcia swd',
#  'Self instruction fast O Co L fst',
#  'Ratgeber swd',
#  'D Erza hlende Literaturgatbeg',
#  'Tables fast O Co L fst',
#  'Pocket watches AAT',
#  'Kongress swd',
#  'Motets fast O Co L fst',
#  'Diaries fast O Co L fst',
#  'Sayings',
#  'Satirelcsh',
#  'Meditations fast O Co L fst',
#  'Contracts fast O Co L fst',
#  'Kongress Mexico Stadt',
#  'Congresses',
#  'Prospectuses England London rbgenr',
#  'Incunabula Italy Venice',
#  'Comediesgsafd',
#  'Aerial views lcgft',
#  'Kongress Davos',
#  'Incunabula Italy Venice th century',
#  'Incunabula Netherlands Deventer',
#  'Diaries lcgft',
#  'Rulesfast O Co L fst',
#  'Breviariesrbgenr',
#  'Kongress',
#  'Inventories fast O Co L fst',
#  'Incunabula Belgium Louvain rbgenr',
#  'Livres a clef gsafd',
#  'Wooden boards rbbin St Ed NL',
#  'Potsdam swd',
#  'Fables gsafd',
#  'Revistes electr niques',
#  'Prospectuses rbgenr',
#  'Occasional sermons England th centuryrbgenr',
#  'Sayings lcgft',
#  'Monografische Reihe gnd content',
#  'Grid plan AAT',
#  'Adaptations fast O Co L fst',
#  'Psalters rbgenr',
#  'Aufsatzsammlungswd',
#  'Legends gsafd',
#  'Satires England th century rbgenr',
#  'Indexes fast O Co L fst',
#  'Congress',
#  'Prospectuses England London th century rbgenr',
#  'Congress DNL',
#  'Satires rbgenr',
#  'Specifications fast O Co L fst',
#  'Greeting cards fast O Co L fst',
#  'Prayers and devotions fast O Co L fst',
#  'Records and correspondencefast O Co L fst',
#  'Sermons English th century rbgenr',
#  'Illegible markings rbrpov',
#  'Bildungsromans',
#  'Birmingham',
#  'Busts figures AAT',
#  'Festschrift mesh',
#  'series marcgt',
#  'Letters rbgenr',
#  'Wills fast O Co L fst',
#  'Parliamentary petitions rbgenr',
#  'Prospectuses Scotland Edinburgh rbgenr',
#  'Crafts',
#  'Trivia and miscellaneafast O Co L fst',
#  'Introductionsfast O Co L fst',
#  'Congress swd',
#  'Zeitschrift',
#  'Slavery',
#  'Incunabula Italy Vicenza',
#  'Breviaries',
#  'Bildband',
#  'Zeitschrift D swd',
#  'Sermons fast O Co L fst',
#  'Introductions fast O Co L fst',
#  'C RO Ms',
#  'Death registers lcgft',
#  'Patternsfast O Co L fst',
#  'Verona swd',
#  'Petitions Scotland th century rbgenr',
#  'Woodcuts aat',
#  'Riga',
#  'Suites fast O Co L fst',
#  'Incunabula Germany Erfurt',
#  'Couplets',
#  'Bills rbgenr',
#  'Terms and phrases fast O Co L fst',
#  'Czasopismo spo eczno polityczne dbn',
#  'Facsimiles fast O Co L fst',
#  'Zeitschriftgnd',
#  'D Lyrikgatbeg',
#  'U Civil War',
#  'Comedies gsafd',
#  'Pamphlets fast O Co L fst',
#  'Satire lcsh',
#  'Parodies imitations etc fast O Co L fst',
#  'Kongress Nagoya',
#  'Sermons Germany Regensburgrbgenr',
#  'Argentina',
#  'Llibres electr nics',
#  'Hymns Scottish Gaelic rbgen',
#  'Congressswd',
#  'Ko ln swd',
#  'Sermons England th centuryrbgen',
#  'Fu hrerswd',
#  'Lande da Aber Wrach swd',
#  'Libros electro nicos',
#  'Toyama swd',
#  'Lissabon swd',
#  'lborg swd',
#  'Letters',
#  'Rio de Janeiro swd',
#  'Indulgences Netherlands rbgenr',
#  'endlager',
#  'Festschrift',
#  'Comedies England th century rbgenr',
#  'Satire fast O Co L fst',
#  'Zines lcgft',
#  'Oval shape AAT',
#  'Zeitschriftgnd content',
#  'Hymns lcgft',
#  'Death registersfast O Co L fst',
#  'Fantasy',
#  'Aufsatzsammlung gnd content',
#  'Zitatensammlungswd',
#  'Fallstudiensammlung',
#  'Looseleafs local',
#  'Preken vorm gtt N Le OC',
#  'Trivia and miscellanea lcgft',
#  'th century',
#  'Bildungsromans lcsh',
#  'Incunabula Italy Florence',
#  'Czasopismo literaturoznawczedbn',
#  'Tanagrafigur swd',
#  'Latter Day Saints',
#  'Seas TGM',
#  'Wo rterbuch swd',
#  'Satiregsafd',
#  'Dystopias fast O Co L fst',
#  'Saint Etienne swd',
#  'Fables rbgenr',
#  'Zeitschrift gnd',
#  'Zhangjiajie swd',
#  'Romances fast O Co L fst',
#  'Incunabula Switzerland Basel',
#  'Sermons English Scotland rbgen',
#  'Venedig swd',
#  'Sermons Germany th centuryrbgenr',
#  'Incunabula Belgium Brussels',
#  'Regulations rbgenr',
#  'Incunabula Italy Milan',
#  'Facsimileslcgft',
#  'Legends fast O Co L fst',
#  'Patternsfast',
#  'Inscriptions England rbprov',
#  'C gnd carrier',
#  'Sourcesfast O Co L fst',
#  'Incunabula Germany Nuremberg',
#  'Fables lcgft',
#  'Elegies England rb genr',
#  'Letters rbgenref',
#  'Mauchline ware Scotland Mauchline local',
#  'Personal correspondence lcgft',
#  'Prophecies fast O Co L fst',
#  'Incunabula Germany Ulm',
#  'Typefaces Type evidence Gold Rush rbtyp',
#  'Imaging systems in astronomy',
#  'Methods Self instruction fast O Co L fst',
#  'Festschriftmesh',
#  'Fables',
#  'Phoenix Ariz swd',
#  'Hymns English fast',
#  'C RO Ms local',
#  'Ausstellung London',
#  'Hymnslcgft',
#  'Regels vorm gtt',
#  'Sermonsrbgenr',
#  'riodiques lectroniques RER rero',
#  'Kongress Cetraro',
#  'Actes de congr s rvmgf',
#  'Incunabula Germany Nuremberg Specimens',
#  'Incunabula Italy Bologna',
#  'Mu nster Westfalen swd',
#  'Patterns fast',
#  'Czasopismo socjologicznedbn',
#  'Zeitschrift D gnd',
#  'Bildungsromans lcgft',
#  'Ponta Delgada swd',
#  'Peking swd',
#  'Funeral sermons rbgenr',
#  'Oslo swd',
#  'Allegories',
#  'Incunabula Germany Cologne lcsh',
#  'Pantomime Christmas entertainment',
#  'Rom swd',
#  'Lehrbuch',
#  'Incunabula France Paris',
#  'Librettos fast O Co L fst',
#  'Incunabula Germany Leipzig',
#  'Incunabulaitaly Venice th century',
#  'Festschriften lcgft',
#  'Letters England th century rbgenr',
#  'Tragediesgsafd',
#  'Voss swd',
#  'Passau',
#  'Educational toys',
#  'Conversion tables fast O Co L fst',
#  'Tours swd',
#  'Tableaux lcgft',
#  'Incunabula Germany Augsburg Specimens',
#  'Kuopio swd',
#  'Spanish language materials',
#  'Indulgences Spain rbgenr',
#  'Calendars rbgenr',
#  'Voyages Imaginary gsafd',
#  'Lenten sermons rbgen',
#  'Erlebnisbericht',
#  'Administrative regulations lcgft',
#  'Romans clef lcgft',
#  'Yellowbacks England rbgenr',
#  'Jokes',
#  'Revues de droit rvmgf',
#  'v Fanzines aat',
#  'Tragicomedy',
#  'Czasopismo filozoficznedbn',
#  'Observations fast O Co L fst',
#  'Paphos Ktima',
#  'Series marcgt',
#  'Sermons England Birmingham rbgenr',
#  'D Zeitschriftgnd content',
#  'Bildungsromans fast O Co L fst',
#  'Convention Montre al Canada',
#  'Parody',
#  'Phuket Stadt swd',
#  'Trivia and miscellanea fast',
#  'Prospectuses Scotland Glasgow th century rbgenr',
#  'Quelle',
#  'Melbourne swd',
#  'Family Saga',
#  'Datensammlung swd',
#  'Kongress Tours',
#  'Linz swd',
#  'Czasopismo o sztucedbn',
#  'Robinsonades gsafd',
#  'Reisebericht swd',
#  'Native America',
#  'Sermons Scotland Edinburgh rbgenr',
#  'Incunabula Italy Treviso',
#  'Paphos Ktima swd',
#  'Facsimiles lcgft',
#  'Diariesfast O Co L fst',
#  'Livres de mode les rvmgf Ca QQ La RVMG',
#  'Paraphrases fast O Co L fst',
#  'Wives AAT',
#  'Las Vegas Nev swd',
#  'Legislation',
#  'Pastoral letters and chargesrbgen',
#  'Folding cameras AAT',
#  'Porto Portugal swd',
#  'Incunabula Italy Bologna rbgenr',
#  'Etchings gmgpc',
#  'San Francisco Calif swd',
#  'Indexes lcgft',
#  'Festschriften aat',
#  'Aufsatzsammlung gnd',
#  'Bildungsromansgsafd',
#  'Romans rvmgf Ca QQ La RVMG',
#  'Pe riodiques rvmgf',
#  'Records Sports fast O Co L fst',
#  'San Sebastia n swd',
#  'Revistes electro niques thub',
#  'Erlebnisberichtswd',
#  'Engravings Germany th century gmgpc',
#  'Maquettes TGM',
#  'Incunabula Germany Strassburg',
#  'Verzeichnis swd',
#  'Llibres electro nicsthub',
#  'Sydney swd',
#  'Incunabula Netherlands',
#  'Incunabula France Strasbourg',
#  'Haiku lcgft',
#  'Letters England th centuryrbgenr',
#  'Marginalia rbprov',
#  'Sketches aat',
#  'Zines fast O Co L fst',
#  'Seoul swd',
#  'Ki s Insel swd',
#  'Bills of mortality rbgenr',
#  'Wood engravings United States st century aat',
#  'Indulgences England rbgenr',
#  'Pilsen swd',
#  'Incunabula Germany Reutlingen',
#  'Competition Unfair Economic aspects European Union Countries',
#  'Tragicomedies rbgenr',
#  'Newport Beach Calif swd',
#  'Libros electro nicos UTDT',
#  'Hymns fast O Co L fst',
#  'Gazetteers England aat',
#  'Salzburg swd',
#  'Incunabula Germany Cologne',
#  'Tables',
#  'Sermons th centuryrbgenr',
#  'Methods fast O Co L fst',
#  'Indulgences England',
#  'The ses et e crits acade miques rvmgf',
#  'Incunabula France Strasbourg rbgenr',
#  'Czasopismo je zykoznawcze dbn',
#  'Glossaries vocabularies etc fast O Co L fst',
#  'Indulgences France rbgenr',
#  'Gazetteers fast O Co L fst',
#  'Mu nchen swd',
#  'Incunabula Italy Treviso rbgenr',
#  'Tarragona swd',
#  'Oxford swd',
#  'South America',
#  'Sermons English th centuryrbgenr',
#  'Libros electr nicos',
#  'Incunabula Germany Mainz',
#  'Palo Alto Calif swd',
#  'Kongress Pienza',
#  'Broiadsides England rbgenr',
#  'Thrillersgsafd',
#  'Satire rbgenr',
#  'Hymnsrbgenr',
#  'Odes rbgenr',
#  'Panjabi language materials',
#  'Terminologyfast O Co L fst',
#  'Lectionaries lcgft',
#  'Slides fast O Co L fst',
#  'Dichtbundels gtt',
#  'Pirates Buccaneers Corsairs etc',
#  'Bericht',
#  'Inverted blocks Scotland rbpri',
#  'Ephemera rbgenr',
#  'Incunabula Italy Veniceca',
#  'Bildbandswd',
#  'Czasopismo psychologiczne dbn',
#  'Legislative materials lcgft',
#  'Plaatwerken vorm gtt',
#  'FA Qs fast O Co L fst',
#  'Verzeichnis',
#  'Belletristische Darstellung',
#  'Sankt Petersburg swd',
#  'Sermons England Wolverhampton rbgenr',
#  'Anthologieswd',
#  'Inscriptions Great Britain rbprov',
#  'Schanghai swd',
#  'Tortoises AAT',
#  'Inscriptions rbprov St Ed N Jolly',
#  'Lehrbuch swd',
#  'Kongress New Orleans La',
#  'Werkverzeichnis',
#  'Kuala Lumpur swd',
#  'Claims fast O Co L fst',
#  'Sophia Antipolis swd',
#  'Briefsammlung',
#  'Sermons English th centuryrbgen',
#  'Verona',
#  'Schedules fast O Co L fst',
#  'Meditations',
#  'Librarians TGM',
#  'Menus England rbgenr',
#  'Engravings England London',
#  'United States',
#  'Christianity',
#  'Quelle gnd',
#  'Showcases AAT',
#  'Miscellaneafast O Co L fst',
#  'Creole dialects English',
#  'Zu rich swd',
#  'Poe sie rvmgf Ca QQ La RVMG',
#  'Maynooth swd',
#  'Hoplite shields AAT',
#  'Menus fast O Co L fst',
#  'Satires gsafd',
#  'Woodcuts Japan th century aat',
#  'Travel',
#  'Indexesfast O Co L fst',
#  'Spanish language materials Bilingual',
#  'Incunabula Germany Augsburg',
#  'Briefsammlung swd',
#  'Sermons O Co L fst fast',
#  'Ulsan swd',
#  'Lausanne swd',
#  'Apologetics th century lcsh',
#  'Irises TGM',
#  'Fallstudiensammlung swd',
#  'York swd',
#  'riodiques rvmgf Ca QQ La RVMG',
#  'Letters India th century rbgenr',
#  'Riddles',
#  'Parati swd',
#  'Czasopismo matematycznedbn',
#  'C RO Ms gtlm',
#  'Festschriftenfast O Co L fst',
#  'Tragicomedy lcsh',
#  'Missals th centuryrbgenr',
#  'New Orleans La swd',
#  'Dystopia',
#  'Cadenzas lcgft',
#  'Ratgebergnd',
#  'Reggio nell Emilia swd',
#  'Czasopismo politologicznedbn',
#  'Tumors x Treatment',
#  'Geschiedenis vorm gtt N Le OC',
#  'Administrative regulationslcgft',
#  'Engravings Scotland Edinburgh gmgpc',
#  'Sermons',
#  'Greek crosses motifs AAT',
#  'Hymnals Africa rbgenr',
#  'Tables Data lcgft',
#  'Materiales en espan ol',
#  'Kongress Edinburgh',
#  'Annuaires rvmgf',
#  'Calendars Germany th centuryrbgenr',
#  'Turin swd',
#  'Vietri sul Mare swd',
#  'Natural products',
#  'Calendars France rbgenr',
#  'Comedy',
#  'Salamanca swd',
#  'Czasopismo chrze cija skie dbn',
#  'Wo rterbuch',
#  'Food industry and trade',
#  'Inscriptions fast O Co L fst',
#  'Montre al swd',
#  'Hymns rbgenr',
#  'Kongress Paris',
#  'C D gnd',
#  'Llibres electro nics',
#  'Ausstellung Dessau',
#  'Festschriften',
#  'Inscriptions rbprov St Ed N',
#  'Macao swd',
#  'Peso da Re gua swd',
#  'Aufsatzsammlung D gnd',
#  'Inscriptions Provenance NN Crbprov',
#  'Labor unions Nigeria',
#  'Typefaces Type evidence Times rbtyp',
#  'Kongress Venedig',
#  'Elegies England th century rbgenr',
#  'Las Palmas de Gran Canaria swd',
#  'D Erza hlende Literatur Anthologiengatbeg',
#  'Wood engravings gmgpc',
#  'Bildungsromans English',
#  'Psaltersrbgenr',
#  'Haiku English',
#  'Dandies lctgm',
#  'Suzhou swd',
#  'Diaries rbgenr',
#  'London swd',
#  'Utopias gsafd',
#  'Myths lcgft',
#  'Bildungsromanlcsh',
#  'Records and briefs lcgft',
#  'F Histoire',
#  'F Voyages et pays',
#  'Librettos lcgft',
#  'Typefaces Type evidence Collis rbtyp',
#  'Slipcases England AAT',
#  'Toulouse swd',
#  'Milton Keynes swd',
#  'Elegies rbgenr',
#  'Prayers England rbgenr',
#  'Ausstellungswd',
#  'Pisa swd',
#  'Sapporo swd',
#  'Dagboeken vorm',
#  'Czasopismo politologiczne dbn',
#  'Prospectuses Belgium Brussels rbgenr',
#  'Suites lcgft',
#  'Prayers lcgft',
#  'Woodcuts fast O Co L fst',
#  'Sermons Scotland Crossmichael th century rbgenr',
#  'Personal correspondencefast O Co L fst',
#  'Wrestlers athletes AAT',
#  'Blogs fast O Co L fst',
#  'Prag swd',
#  'Letters th century rbgenr',
#  'Funeral sermonsrbgenr',
#  'Riddles lcgft',
#  'Bandes dessine es de monstres rvmgf Ca QQ La RVMG',
#  'Creeds fast O Co L fst',
#  'Utrecht swd',
#  'Kongress Oulu',
#  'Piggy banks AAT',
#  'Copper engravings Italy Rome th century aat',
#  'Tokio swd',
#  'Controlled Clinical Trial',
#  'Legislationthub',
#  'Rhodos Stadt swd',
#  'Zeist swd',
#  'Traite Montre al Canada',
#  'Arctic areas AAT',
#  'Sermons Scotland Cumbernauld th century rbgenr',
#  'Bildungsromans German',
#  'Fables Latin',
#  'D Krimis Thriller Spionagegatbeg',
#  'Libros electr nicos UTDT',
#  'Typefaces Type evidence Keyboard rbtyp',
#  'Bilingual materials Portuguese English',
#  'Kongress Delft',
#  'Uppsala swd',
#  'Etchings England London gmgpc',
#  'Fables Greek',
#  'Tragedies England th century rbgenr',
#  'Kongress dagstuhl swd',
#  'Comedies rbgenr',
#  'Stockholm swd',
#  'Revistasabne',
#  'Type specimens United States st century rbgenr',
#  'Beispielsammlung swd',
#  'Catechismsrbgenr',
#  'DV Ds England aat',
#  'Obituaries fast O Co L fst',
#  'Nizza swd',
#  'Romances',
#  'Prayers',
#  'Decorative wall components AAT',
#  'Romans teksten gtt N Le OC',
#  'Court decisions and opinions fast O Co L fst',
#  'Jena',
#  'Sermons England rbgenr',
#  'Kongress Cesenatico',
#  'Tsukuba swd',
#  'Death masks AAT',
#  'Bildband swd',
#  'Nara swd',
#  'Nowosibirsk swd',
#  'Rocquencourt swd',
#  'Kongress Riverside Calif',
#  'Catechisms rbgenr',
#  'Librettos rbgenr',
#  'Onlays rbbin',
#  'Ausstellung York',
#  'Terrorist thrillers',
#  'Elegies Scotland th century rbgenr',
#  'Comptes rendus rvmgf',
#  'Petitions rbgenr',
#  'Chronologies fast O Co L fst',
#  'Political satire',
#  'Riga swd',
#  'Court decisions and opinions lcgft',
#  'Sermons Germany th centuryrbgen',
#  'Typefaces Type evidence Ricochet rbtyp',
#  'Concordances fast O Co L fst',
#  'Santiago de Chile swd',
#  'Psychological thrillers',
#  'Devotional calendars lcgft',
#  'Chine colle process AAT',
#  'Saint Malo swd',
#  'Yokohama swd',
#  'War and conflict local',
#  'Powies c angielska w t umaczenia polskie',
#  'Canada',
#  'Czasopismo etnograficzne dbn',
#  'Einfu hrung',
#  'Wooden boards Scotland rbbin St Ed N Cambusk',
#  'Dystopiasgsafd',
#  'Mystery gsafd',
#  'Microscopes AAT',
#  'Toccatas fast O Co L fst',
#  'Calendars Scotland th century rbgenr',
#  'Type faces Type evidence Endeavour rbtyp',
#  'Schedulesfast O Co L fst',
#  'Incunabula Spain Seville',
#  'nsberg',
#  'Facetiae rbgenr',
#  'Registers vorm gtt N Le OC',
#  'Pastoral letters and charges fast O Co L fst',
#  'Prospectuses Scotland rbgenr',
#  'DV RO Ms',
#  'Juvenile materials local',
#  'Logic Symbolic and mathematical',
#  'Christmas pantomimes rbgenr',
#  'Letters correspondence England aat',
#  'Tours fast O Co L fst',
#  'Washington D swd',
#  'Farces gsafd',
#  'Engravings Scotland Glasgow th century gmgpc',
#  'Satire gsafd',
#  'Pe riodiques RER rero',
#  'Exposition Montmorency Muse e Jean Jacques Rousseau',
#  'Pharmacopoeias Scotland Edinburgh rbgenr',
#  'Records and correspondence fast',
#  'Paphos swd',
#  'Binders tickets Scotland Forres rbbin St Ed NL',
#  'Eagles birds AAT',
#  'Sermons Scotland Glasgow rbgenr',
#  'Satires England rbgenr',
#  'Fu hrer idszbz',
#  'Santa Barbara Calif swd',
#  'Tracts England Liverpool rbgenr',
#  'Bildungsroman',
#  'Fables fast O Co L fst',
#  'Ouvrages pour la jeunesse',
#  'Fu hrer',
#  'Sermons lcgft',
#  'Hymnals rbgenr',
#  'Tu bingen swd',
#  'Incunabula Italy Brescia rbgenr',
#  'Lesson plans lcgft',
#  'Power Social sciences',
#  'Tablesfast O Co L fst',
#  'D Aufsatzsammlunggnd content',
#  'Udine swd',
#  'Nagoya swd',
#  'Cries England London rbgenr',
#  'Konferenzschrift gnd',
#  'Journaux rvmgf',
#  'I Poesia',
#  'Trient swd',
#  'Typefaces Garamond Canada aat',
#  'Christmas cards TGM',
#  'Psalters France Paris th century rbgenr',
#  'Coats of arms TGM',
#  'Wien',
#  'Sewing tools and equipment AAT',
#  'Paderborn swd',
#  'Kongress Sa o Luis Maranha o',
#  'Schriftenreihe',
#  'Lean manufacturing',
#  'Ratgeber gnd',
#  'Architektur',
#  'Montpellier swd',
#  'Belletristische Darstellungswd',
#  'Europe Relations Russia',
#  'Riddles rbgenr',
#  'Revista electr nica',
#  'Oberwolfach swd',
#  'Cozy mysteries lcgft',
#  'Thrillers']
